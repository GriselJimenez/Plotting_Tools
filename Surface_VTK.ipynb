# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from IPython.display import Image

import numpy as np
import pandas as pd

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Import the Surf_VTK.py

# %%
import Surf_VTK as Surf

# %% [markdown]
# # Example 1

# %% [markdown]
# ## Generate an exmple surface

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)


# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=10)

plt.show()

# %% [markdown]
# ## Get the X, Y, Z describing the surface

# %%
x=np.reshape(X,(-1,1))
y=np.reshape(Y,(-1,1))
z=np.reshape(Z,(-1,1))

# %% [markdown]
# ## Generate the VTK file

# %%
Surf.Surafce_VTK(x,y,z,flname='Surface.vtk')

# %% [markdown]
# ## Load the vtk file in paraview and save a screenshot

# %%
Image(filename='Paraview1.png',format='png')
